# %%
palabra=input("Ingrese una frase")
vocal= input("ingrese una vocal")

# %%
if vocal.lower() in palabra.lower():
    indice=palabra.find(vocal.lower())
    print(palabra.find(vocal.lower()))
    print(palabra[:indice].lower().strip(),palabra[indice].upper(),palabra[(indice+1):len(palabra)].lower().strip())
# Out:
# 3
# hol A a todos

# %%
if vocal.lower() in palabra.lower():
    print(palabra.replace(vocal.lower(),vocal.upper()))
# Out:
# fAltA poco pAl mundiAl

# %%
indice+1
# Out:
# 4
